# %% [markdown]
# ## Import module/モジュールをインポート

# %%
import MecabParserModule
from MecabParserModule import *

import importlib #Use importlib to reload MecabParserModule during testing
importlib.reload(MecabParserModule)

parser = MecabParser(file_path) #Instantiate class MecabParser
file_path = "./data/nlp_str.txt" #Specify path of file for analysis

# %% [markdown]
# ## Output all parsed results/すべての解析結果を出力

# %%
parser.initial_parse()
# Out:
#              0           1           2                 3             4  \
# 0           自然         シゼン         シゼン                自然    名詞-普通名詞-一般
# 1           言語         ゲンゴ         ゲンゴ                言語    名詞-普通名詞-一般
# 2           処理         ショリ         ショリ                処理  名詞-普通名詞-サ変可能
# 3            （         NaN         NaN                 （      補助記号-括弧開
# 4          しぜん         シゼン         シゼン                自然        形状詞-一般
# 5           げん          ゲン          ゲン                 弦    名詞-普通名詞-一般
# 6            ご           ゴ           ゴ                 御    接尾辞-名詞的-一般
# 7           しょ          ショ          デス                です           助動詞
# 8            り           リ           リ                 り           助動詞
# 9            、         NaN         NaN                 、       補助記号-読点
# 10          英語         エーゴ         エイゴ                英語    名詞-普通名詞-一般
# 11           :         NaN         NaN                 ：       補助記号-一般
# ...

# %% [markdown]
# ## Output only words, pronunciations, and parts of speech/単語、フリガナ、品詞のみを出力

# %%
parser.clean_parse()
# Out:
#     単語    振り仮名            品詞
# 0    一      いち         名詞-数詞
# 1   一連    いちれん    名詞-普通名詞-一般
# 2   人工    じんこう    名詞-普通名詞-一般
# 3   人間    にんげん    名詞-普通名詞-一般
# 4   処理     しょり  名詞-普通名詞-サ変可能
# 5   分野     ぶんや    名詞-普通名詞-一般
# 6    学      がく    接尾辞-名詞的-一般
# 7   技術    ぎじゅつ    名詞-普通名詞-一般
# 8   日常   にちじょう  名詞-普通名詞-副詞可能
# 9   略称  りゃくしょう  名詞-普通名詞-サ変可能
# 10   的      てき      接尾辞-形状詞的
# 11  知能     ちのう    名詞-普通名詞-一般
# 12  自然     しぜん    名詞-普通名詞-一般
# 13  英語     えいご    名詞-普通名詞-一般
# 14  言語     げんご    名詞-普通名詞-一般
