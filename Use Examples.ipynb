# %%
from MecabParserModule import *

# file_path = "./data/engi_str.txt"
file_path = "./data/nlp_str.txt"


parser = MecabParser(file_path)
parser.initial_parser()
# Out:
#              0           1           2             3         4       5
# 0           言語         ゲンゴ          言語         名詞-一般       NaN     NaN
# 1           処理         ショリ          処理       名詞-サ変接続       NaN     NaN
# 2            （           （           （        記号-括弧開       NaN     NaN
# 3            し           シ          する         動詞-自立     サ変・スル     連用形
# 4           ぜん          ゼン          ぜん         名詞-一般       NaN     NaN
# 5           げん          ゲン          げん         名詞-一般       NaN     NaN
# 6          ごしょ         ゴショ         ごする         動詞-自立    サ変・−スル   未然ウ接続
# 7            り           リ           り           助動詞      文語・リ     基本形
# 8            、           、           、         記号-読点       NaN     NaN
# 9           英語         エイゴ          英語         名詞-一般       NaN     NaN
# 10           :           :           :       名詞-サ変接続       NaN     NaN
# 11     natural     natural     natural         名詞-一般       NaN     NaN
# ...

# %%
parser.clean_parser()
# Out:
#     単語    フリガナ            品詞
# 0    一      イチ          名詞-数
# 1   一連    イチレン         名詞-一般
# 2   人工    ジンコウ         名詞-一般
# 3   人間    ニンゲン         名詞-一般
# 4   処理     ショリ       名詞-サ変接続
# 5   分野     ブンヤ         名詞-一般
# 6    学      ガク      名詞-接尾-一般
# 7   技術    ギジュツ         名詞-一般
# 8   日常   ニチジョウ         名詞-一般
# 9   略称  リャクショウ       名詞-サ変接続
# 10   的      テキ  名詞-接尾-形容動詞語幹
# 11  知能     チノウ         名詞-一般
# 12  自然     シゼン     名詞-形容動詞語幹
# 13  英語     エイゴ         名詞-一般
# 14  言語     ゲンゴ         名詞-一般

# %%
kata_table = parser.hiragana_parser()

type(kata_table)
#pandas.core.frame.DataFrame
kata_table
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /Users/aw/Google_Drive/IT/GitHub/ja_vocab_generator_200919-/Japanese-Vocabulary-Generator/MecabParserModule.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     単語    ふりがな            品詞
# 0    一      いち          名詞-数
# 1   一連    いちれん         名詞-一般
# 2   人工    じんこう         名詞-一般
# 3   人間    にんげん         名詞-一般
# 4   処理     しょり       名詞-サ変接続
# 5   分野     ぶんや         名詞-一般
# 6    学      がく      名詞-接尾-一般
# ...

# %%
import re
import requests
import time

from bs4 import BeautifulSoup
from random import random
from selenium import webdriver
    
def get_jp_stress(vocab_list):

    driver = webdriver.Chrome(executable_path='/Users/aw/Google_Drive/IT/PYTHON/chromedriver')
    search_string = vocab_list
    just_a_sec = random() 
    pattern = r'［\d\］'  #Location accents such as [0] or [2]
    
    stress_list =[]
    word_stress_list =[]
    
    for word in vocab_list:
        search_site = "https://www.weblio.jp/content/" + word
        driver.get(search_site)
        time.sleep(just_a_sec * 1)
        
        try:
#             all_ele = driver.find_element_by_xpath('//*[@id="cont"]') #get all elements
            for ele in driver.find_elements_by_class_name('midashigo'):
                match = re.search(pattern, ele.text)
                if match:
                    stress = match.group(0)
                    word_stress = ele.text
                    break
                    
        except:
#             stress_list.append("[]")
#             word_stress_list.append("")
            stress = "[]"
            word_stress = ""
            
        stress_list.append(stress)
        word_stress_list.append(word_stress)
        
        print(f"{word}/{stress}/{word_stress}")
            
                    
#     time.sleep(10)
    driver.quit()
                    
    return stress_list, word_stress_list

# %%
result = kata_table

vocab_list = result.iloc[:, 0]

list_of_words = []
count = 0
for i in vocab_list:
    list_of_words.append(i)
    
list_of_words
# Out:
# ['一',
#  '一連',
#  '人工',
#  '人間',
#  '処理',
#  '分野',
#  '学',
#  '技術',
#  '日常',
#  '略称',
#  '的',
#  '知能',
#  '自然',
#  '英語',
#  '言語']

# %%
####Get pitch accents####

stress_list, word_stress_list = get_jp_stress(list_of_words)
print(f"stress_list: {stress_list}")
print(f"word_stress_list: {word_stress_list}")
# Out:
# 一/［1］/イー ［1］ 【一】
# 一連/［0］/いち れん ［0］ 【一連】
# 人工/［0］/じん こう ［0］ 【人工】
# 人間/［0］/じん かん ［0］【人間】
# 処理/［1］/しょ り ［1］ 【処理】
# 分野/［1］/ぶん や ［1］【分野】
# 学/［0］/がく ［0］［1］ 【学】
# 技術/［1］/ぎ じゅつ ［1］【技術】
# 日常/［0］/にち じょう －じやう ［0］ 【日常】
# 略称/［0］/りゃく しょう ［0］【略称】
# 的/［0］/まと ［0］【的】
# 知能/［1］/ち のう ［1］【知能・智▼能】
# 自然/［0］/し ぜん ［0］ 【自然】
# 英語/［0］/えい ご ［0］【英語】
# 言語/［1］/げん ご ［1］【言語】
# stress_list: ['［1］', '［0］', '［0］', '［0］', '［1］', '［1］', '［0］', '［1］', '［0］', '［0］', '［0］', '［1］', '［0］', '［0］', '［1］']
# word_stress_list: ['イー ［1］ 【一】', 'いち れん ［0］ 【一連】', 'じん こう ［0］ 【人工】', 'じん かん ［0］【人間】', 'しょ り ［1］ 【処理】', 'ぶん や ［1］【分野】', 'がく ［0］［1］ 【学】', 'ぎ じゅつ ［1］【技術】', 'にち じょう －じやう ［0］ 【日常】', 'りゃく しょう ［0］【略称】', 'まと ［0］【的】', 'ち のう ［1］【知能・智▼能】', 'し ぜん ［0］ 【自然】', 'えい ご ［0］【英語】', 'げん ご ［1］【言語】']

# %%
df = pd.DataFrame(data={"list_of_words": list_of_words, "stress_list": stress_list, "word_stress_list": word_stress_list})
df
# Out:
#    list_of_words stress_list      word_stress_list
# 0              一         ［1］            イー ［1］ 【一】
# 1             一連         ［0］        いち れん ［0］ 【一連】
# 2             人工         ［0］        じん こう ［0］ 【人工】
# 3             人間         ［0］         じん かん ［0］【人間】
# 4             処理         ［1］         しょ り ［1］ 【処理】
# 5             分野         ［1］          ぶん や ［1］【分野】
# 6              学         ［0］         がく ［0］［1］ 【学】
# 7             技術         ［1］         ぎ じゅつ ［1］【技術】
# 8             日常         ［0］  にち じょう －じやう ［0］ 【日常】
# 9             略称         ［0］       りゃく しょう ［0］【略称】
# 10             的         ［0］             まと ［0］【的】
# 11            知能         ［1］      ち のう ［1］【知能・智▼能】
# 12            自然         ［0］         し ぜん ［0］ 【自然】
# 13            英語         ［0］          えい ご ［0］【英語】
# 14            言語         ［1］          げん ご ［1］【言語】

# %%
new_result = result[:]
new_result.insert(2, "アクセント", stress_list)
new_result
# Out:
#     単語    ふりがな アクセント            品詞
# 0    一      いち   ［1］          名詞-数
# 1   一連    いちれん   ［0］         名詞-一般
# 2   人工    じんこう   ［0］         名詞-一般
# 3   人間    にんげん   ［0］         名詞-一般
# 4   処理     しょり   ［1］       名詞-サ変接続
# 5   分野     ぶんや   ［1］         名詞-一般
# 6    学      がく   ［0］      名詞-接尾-一般
# 7   技術    ぎじゅつ   ［1］         名詞-一般
# 8   日常   にちじょう   ［0］         名詞-一般
# 9   略称  りゃくしょう   ［0］       名詞-サ変接続
# 10   的      てき   ［0］  名詞-接尾-形容動詞語幹
# 11  知能     ちのう   ［1］         名詞-一般
# 12  自然     しぜん   ［0］     名詞-形容動詞語幹
# 13  英語     えいご   ［0］         名詞-一般
# 14  言語     げんご   ［1］         名詞-一般
